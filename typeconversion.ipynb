# %%
#--> Type Conversion ( converting one data type to another data type)
#... 1. Implicit ( no need to declare the data type for values the interpeter automatically detects and returns values )
#... 2. Explicit ( we need to convert the data type of a value manually using builtin functions Str(), int(), etc,..  )
# Out:
# 10
# 9.5
# (5+5j)
# 19.5
# (19+7j)

# %%
#....> Implicit ( Boolean -> Int -> float -> complex)
# case1: boolean
a=True
b=9 # integer
print(a+b) # returns integer
a= False
b= 9.5 # Float
print(a+b)# returns Float
a= True
b= 4+5j # complex
print(a+b) # reuren complex

# case2 : Integer
a=10
b=9.5 # Flaot
print(a+b) # retrun float
a=14
b=5+7j # complex
print(a+b)
# Out:
# 10
# 9.5
# (5+5j)
# 19.5
# (19+7j)

# %%
# ..> Explicit 

#case1 : int ( int is not iterable hence it cant convert into list, set, dic, tuple )
a=10
k=float(a)
print(k) # converts int into Float
b= bool(a)
print(b) # conerts int into boolean
s= str(a)
print(s) # converts int into string
# x= list(a)  # int not iterable hence cant convert
# y= tuple(a)   # int not iterable hence cant convert
# z= set(a)     # int not iterable hence cant convert

#case2 : Float  ( float is not iterable hence it cant convert into list, set, dic, tuple )
a=17.7
i= int(a)
print(i)
b= bool(a)
print(b)
c=str(a)
print(c)
# x= list(a)  # float not iterable hence cant convert
# y= tuple(a)   # float not iterable hence cant convert
# z= set(a)     # float not iterable hence cant convert

#case3 : String ( Str cant convert into int, flaot if it is character string, if str is int then it will convert into int, float )
        # str cant convert into dic as it as no key-value pair

s= "Sriram"
l=list(s)
print(l)
s=set(s)
print(s)
print(tuple(s))

k= "1908"
l=list(k)
print(l)
s=set(k)
print(s)
print(tuple(k))
#print(dict(s))

# case4: List  ( list cant convert into int, float, dic)
l= [1,4,7,4,7]
#i=int(l)
#print(i)
#print(float(l))
print(str(l))
print(set(l))
print(tuple(l))
 # case5: tuple ( tuple cant be converted into int, float, dic)
t=(1,4,6,7,3,7)
#print(int(t))
print(list(t))
print(str(t))
print(set(t))

#case6: set
# Out:
# 10.0
# True
# 10
# 17
# True
# 17.7
# ['S', 'r', 'i', 'r', 'a', 'm']
# {'i', 'r', 'S', 'a', 'm'}
# ('i', 'r', 'S', 'a', 'm')
# ['1', '9', '0', '8']
# {'9', '8', '1', '0'}
# ('1', '9', '0', '8')
# [1, 4, 7, 4, 7]
# {1, 4, 7}
# (1, 4, 7, 4, 7)
# [1, 4, 6, 7, 3, 7]
# (1, 4, 6, 7, 3, 7)
# {1, 3, 4, 6, 7}
