# %%
# --> COnditional Statemnets / Decision Making 
# .. if, ifelse, elif, nestedif

# 1.. if statements
n= int(input(" enter the integer"))
if n>=18:
    print("elgible")
else: 
    print("not elgible")
# Out:
#  enter the integer 12
# not elgible

# %%
n = int(input())
if n % 2 == 0:
    print("even")
else: 
    print("odd")
# Out:
#  57
# odd

# %%
a = int(input())
b= int(input())
if a>b :
    print(a)
else:
    print(b)
# Out:
#  56
#  32
# 56

# %%
year = int(input())
if (year % 4 ==0 and year % 100 != 0) or year % 400 == 0:
    print("leap year")
else:
    print("not")
# Out:
#  2520
# leap year

# %%
a= 13
b= 27
c=17
if a>(b and c):
    print(a)
elif b> (a and c):
    print(b)
else:
    print(c)
# Out:
# 27

# %%
x= int(input())
if x ==0:
    print("neutral")
elif x < 0:
    print("-ve")
else:
    print("+ve")
# Out:
#  0
# neutral

# %%
x = input()
if x.isupper():
    print("upper")
elif x.islower():
    print("lower")
else:
    print("not letter")
# Out:
#  0
# not letter

# %%
x= int(input("enter the age"))
if 0<x<=5:
    print("no ticket child")
elif 6<= x <12 :
    print(" half ticket " )
elif 12<= x < 60 :
    print(" full ticket ")
elif x >=60:
    print("senior citizen")
else:
    print("invalid age")
# Out:
# enter the age 0
# invalid age
