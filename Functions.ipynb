# %%
# Functions : Resuable block of code
# Syntax :  Def Fun_name():
#                return value / Block of code
#            Fun_name()

# %%
def add(a,b):
    print(a+b)
add(4,5)
# Out:
# 9

# %%
def ev(a):
    even=[]
    odd = []
    for i in a:
        if i % 2 ==0:
            even.append(i)
        else:
            odd.append(i)
    return even,odd
ev([1,2,3,4,5])
# Out:
# ([2, 4], [1, 3, 5])
